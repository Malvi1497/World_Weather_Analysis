# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 740

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nyurba
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | galveston
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | changli
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | lorengau
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | puerto escondido
# Processing Record 15 of Set 1 | dongtai
# Processing Record 16 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | meulaboh
# Processing Record 19 of Set 1 | gizo
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | laguna
# Processing Record 22 of Set 1 | bismarck
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | carballo
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | iqaluit
# Processing Record 27 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | larsnes
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | jaca
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | ankang
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | ostrovnoy
# Processing Record 44 of Set 1 | bambous virieux
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | fort nelson
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | louga
# Processing Record 49 of Set 1 | port augusta
# Processing Record 50 of Set 1 | margate
# Processing Record 1 of Set 2 | victoria point
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | kavaratti
# Processing Record 4 of Set 2 | provideniya
# Processing Record 5 of Set 2 | abu samrah
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 2 | zyukayka
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | coihaique
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | menongue
# Processing Record 13 of Set 2 | mehamn
# Processing Record 14 of Set 2 | pangkalanbuun
# Processing Record 15 of Set 2 | hualmay
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | red bluff
# Processing Record 18 of Set 2 | pinawa
# Processing Record 19 of Set 2 | westport
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | college
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | takayama
# Processing Record 25 of Set 2 | lasa
# Processing Record 26 of Set 2 | acari
# Processing Record 27 of Set 2 | khovu-aksy
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | lavrentiya
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 2 | rawson
# Processing Record 36 of Set 2 | yorkton
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | raudeberg
# Processing Record 39 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | bang krathum
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | domoni
# Processing Record 43 of Set 2 | weligama
# Processing Record 44 of Set 2 | hamilton
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | selfoss
# Processing Record 47 of Set 2 | biak
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | faanui
# Processing Record 50 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 3 | yenangyaung
# Processing Record 2 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 3 | takoradi
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | iringa
# Processing Record 6 of Set 3 | nago
# Processing Record 7 of Set 3 | ilulissat
# Processing Record 8 of Set 3 | aliganj
# Processing Record 9 of Set 3 | winnemucca
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | kobayashi
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | quatre cocos
# Processing Record 14 of Set 3 | castro
# Processing Record 15 of Set 3 | yulara
# Processing Record 16 of Set 3 | natal
# Processing Record 17 of Set 3 | east london
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | bilibino
# Processing Record 20 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 3 | changqing
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | great falls
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | xining
# Processing Record 26 of Set 3 | praia
# Processing Record 27 of Set 3 | haines junction
# Processing Record 28 of Set 3 | kindu
# Processing Record 29 of Set 3 | labuan
# Processing Record 30 of Set 3 | demba
# Processing Record 31 of Set 3 | sondrio
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | marzuq
# Processing Record 34 of Set 3 | matara
# Processing Record 35 of Set 3 | mayumba
# Processing Record 36 of Set 3 | fallon
# Processing Record 37 of Set 3 | panama city
# Processing Record 38 of Set 3 | aklavik
# Processing Record 39 of Set 3 | nicoya
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | lakes entrance
# Processing Record 42 of Set 3 | jamestown
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | whitehorse
# Processing Record 46 of Set 3 | stromness
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | naantali
# Processing Record 49 of Set 3 | yuncheng
# Processing Record 50 of Set 3 | luanda
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | ulvik
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | hof
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | rudnichnyy
# Processing Record 8 of Set 4 | mareeba
# Processing Record 9 of Set 4 | buraydah
# Processing Record 10 of Set 4 | port hedland
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | kushiro
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | malangali
# Processing Record 15 of Set 4 | salalah
# Processing Record 16 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 17 of Set 4 | goundi
# Processing Record 18 of Set 4 | dundwaraganj
# Processing Record 19 of Set 4 | opuwo
# Processing Record 20 of Set 4 | new norfolk
# Processing Record 21 of Set 4 | pacific grove
# Processing Record 22 of Set 4 | sal rei
# Processing Record 23 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | arroio grande
# Processing Record 26 of Set 4 | bloomfield
# Processing Record 27 of Set 4 | broken hill
# Processing Record 28 of Set 4 | sarakhs
# Processing Record 29 of Set 4 | lagoa
# Processing Record 30 of Set 4 | ust-maya
# Processing Record 31 of Set 4 | pingliang
# Processing Record 32 of Set 4 | okhotsk
# Processing Record 33 of Set 4 | bengkulu
# Processing Record 34 of Set 4 | sao gabriel da cachoeira
# Processing Record 35 of Set 4 | hervey bay
# Processing Record 36 of Set 4 | norden
# Processing Record 37 of Set 4 | hay river
# Processing Record 38 of Set 4 | clyde river
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | cap-aux-meules
# Processing Record 41 of Set 4 | riyadh
# Processing Record 42 of Set 4 | seoul
# Processing Record 43 of Set 4 | fortuna
# Processing Record 44 of Set 4 | kisaran
# Processing Record 45 of Set 4 | moba
# Processing Record 46 of Set 4 | geraldton
# Processing Record 47 of Set 4 | kasongo-lunda
# Processing Record 48 of Set 4 | bundibugyo
# Processing Record 49 of Set 4 | mongo
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | saint-augustin
# Processing Record 4 of Set 5 | nizwa
# Processing Record 5 of Set 5 | cassilandia
# Processing Record 6 of Set 5 | santa vitoria do palmar
# Processing Record 7 of Set 5 | vao
# Processing Record 8 of Set 5 | camacha
# Processing Record 9 of Set 5 | dunedin
# Processing Record 10 of Set 5 | majene
# Processing Record 11 of Set 5 | bemidji
# Processing Record 12 of Set 5 | benghazi
# Processing Record 13 of Set 5 | yuli
# Processing Record 14 of Set 5 | lata
# Processing Record 15 of Set 5 | cordoba
# Processing Record 16 of Set 5 | tuy hoa
# Processing Record 17 of Set 5 | la palma
# Processing Record 18 of Set 5 | touros
# Processing Record 19 of Set 5 | aksha
# Processing Record 20 of Set 5 | ahuimanu
# Processing Record 21 of Set 5 | matagami
# Processing Record 22 of Set 5 | gorontalo
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 5 | navahrudak
# Processing Record 26 of Set 5 | komsomolskiy
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | melekhovskaya
# City not found. Skipping...
# Processing Record 29 of Set 5 | simnas
# Processing Record 30 of Set 5 | jian
# Processing Record 31 of Set 5 | belaya gora
# Processing Record 32 of Set 5 | pevek
# Processing Record 33 of Set 5 | chapais
# Processing Record 34 of Set 5 | ajdabiya
# Processing Record 35 of Set 5 | sorong
# Processing Record 36 of Set 5 | hasaki
# Processing Record 37 of Set 5 | kinlochleven
# Processing Record 38 of Set 5 | skegness
# Processing Record 39 of Set 5 | naze
# Processing Record 40 of Set 5 | leningradskiy
# Processing Record 41 of Set 5 | virginia beach
# Processing Record 42 of Set 5 | ozark
# Processing Record 43 of Set 5 | amga
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | balakhninskiy
# Processing Record 46 of Set 5 | nemuro
# Processing Record 47 of Set 5 | elban
# Processing Record 48 of Set 5 | ararat
# Processing Record 49 of Set 5 | balabac
# Processing Record 50 of Set 5 | rio gallegos
# Processing Record 1 of Set 6 | hobyo
# Processing Record 2 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 6 | coahuayana
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | vicuna
# Processing Record 6 of Set 6 | yeppoon
# Processing Record 7 of Set 6 | sanary-sur-mer
# Processing Record 8 of Set 6 | togur
# Processing Record 9 of Set 6 | elko
# Processing Record 10 of Set 6 | cananea
# Processing Record 11 of Set 6 | la asuncion
# Processing Record 12 of Set 6 | upernavik
# Processing Record 13 of Set 6 | katsuura
# Processing Record 14 of Set 6 | tarakan
# Processing Record 15 of Set 6 | evensk
# Processing Record 16 of Set 6 | dharmadam
# Processing Record 17 of Set 6 | timra
# Processing Record 18 of Set 6 | imeni babushkina
# Processing Record 19 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 6 | san policarpo
# Processing Record 21 of Set 6 | vestmannaeyjar
# Processing Record 22 of Set 6 | brainerd
# Processing Record 23 of Set 6 | ekhabi
# Processing Record 24 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 6 | walvis bay
# Processing Record 26 of Set 6 | berlevag
# Processing Record 27 of Set 6 | fier
# Processing Record 28 of Set 6 | thompson
# Processing Record 29 of Set 6 | luderitz
# Processing Record 30 of Set 6 | port hardy
# Processing Record 31 of Set 6 | bolshoye nagatkino
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | parrita
# Processing Record 34 of Set 6 | lexington
# Processing Record 35 of Set 6 | nantucket
# Processing Record 36 of Set 6 | husavik
# Processing Record 37 of Set 6 | guerrero negro
# Processing Record 38 of Set 6 | richards bay
# Processing Record 39 of Set 6 | bolshiye uki
# City not found. Skipping...
# Processing Record 40 of Set 6 | nabire
# Processing Record 41 of Set 6 | prince rupert
# Processing Record 42 of Set 6 | wanning
# Processing Record 43 of Set 6 | sur
# Processing Record 44 of Set 6 | faya
# Processing Record 45 of Set 6 | sann
# Processing Record 46 of Set 6 | chaihe
# Processing Record 47 of Set 6 | talnakh
# Processing Record 48 of Set 6 | havelock
# Processing Record 49 of Set 6 | nioro
# Processing Record 50 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 7 | vidim
# Processing Record 2 of Set 7 | formosa
# Processing Record 3 of Set 7 | sapu
# Processing Record 4 of Set 7 | inhambane
# Processing Record 5 of Set 7 | huesca
# Processing Record 6 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 7 | longyearbyen
# Processing Record 8 of Set 7 | esperance
# Processing Record 9 of Set 7 | palmer
# Processing Record 10 of Set 7 | ahipara
# Processing Record 11 of Set 7 | sitka
# Processing Record 12 of Set 7 | itarema
# Processing Record 13 of Set 7 | liuli
# Processing Record 14 of Set 7 | sao jose da coroa grande
# Processing Record 15 of Set 7 | arti
# Processing Record 16 of Set 7 | asau
# Processing Record 17 of Set 7 | tabas
# Processing Record 18 of Set 7 | vila do maio
# Processing Record 19 of Set 7 | kupang
# Processing Record 20 of Set 7 | pisco
# Processing Record 21 of Set 7 | mabaruma
# Processing Record 22 of Set 7 | eureka
# Processing Record 23 of Set 7 | nexo
# Processing Record 24 of Set 7 | urengoy
# Processing Record 25 of Set 7 | tadine
# Processing Record 26 of Set 7 | matamoros
# Processing Record 27 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 7 | sawtell
# Processing Record 29 of Set 7 | port macquarie
# Processing Record 30 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 31 of Set 7 | florence
# Processing Record 32 of Set 7 | san jose
# Processing Record 33 of Set 7 | grindavik
# Processing Record 34 of Set 7 | dakar
# Processing Record 35 of Set 7 | makakilo city
# Processing Record 36 of Set 7 | ambilobe
# Processing Record 37 of Set 7 | badin
# Processing Record 38 of Set 7 | lake havasu city
# Processing Record 39 of Set 7 | sassandra
# Processing Record 40 of Set 7 | wanaka
# Processing Record 41 of Set 7 | sawakin
# Processing Record 42 of Set 7 | huangmei
# Processing Record 43 of Set 7 | kiunga
# Processing Record 44 of Set 7 | tokmak
# Processing Record 45 of Set 7 | damara
# Processing Record 46 of Set 7 | roebourne
# Processing Record 47 of Set 7 | luebo
# Processing Record 48 of Set 7 | buchanan
# Processing Record 49 of Set 7 | nakusp
# Processing Record 50 of Set 7 | georgetown
# Processing Record 1 of Set 8 | halifax
# Processing Record 2 of Set 8 | merauke
# Processing Record 3 of Set 8 | terre-de-bas
# Processing Record 4 of Set 8 | monrovia
# Processing Record 5 of Set 8 | oranjemund
# Processing Record 6 of Set 8 | la union
# Processing Record 7 of Set 8 | puxinana
# Processing Record 8 of Set 8 | nguruka
# Processing Record 9 of Set 8 | yashkul
# Processing Record 10 of Set 8 | marsh harbour
# Processing Record 11 of Set 8 | kavieng
# Processing Record 12 of Set 8 | tasiilaq
# Processing Record 13 of Set 8 | ulkan
# Processing Record 14 of Set 8 | gbarnga
# Processing Record 15 of Set 8 | calvinia
# Processing Record 16 of Set 8 | oxelosund
# Processing Record 17 of Set 8 | port blair
# Processing Record 18 of Set 8 | ouadda
# Processing Record 19 of Set 8 | henties bay
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | north bend
# Processing Record 22 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 8 | vila
# Processing Record 24 of Set 8 | vanavara
# Processing Record 25 of Set 8 | owando
# Processing Record 26 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 8 | yerbogachen
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 8 | lethem
# Processing Record 31 of Set 8 | dzaoudzi
# Processing Record 32 of Set 8 | nelson bay
# Processing Record 33 of Set 8 | turukhansk
# Processing Record 34 of Set 8 | maralal
# Processing Record 35 of Set 8 | nelson
# Processing Record 36 of Set 8 | adrar
# Processing Record 37 of Set 8 | srednekolymsk
# Processing Record 38 of Set 8 | uray
# Processing Record 39 of Set 8 | nuuk
# Processing Record 40 of Set 8 | sile
# Processing Record 41 of Set 8 | machilipatnam
# Processing Record 42 of Set 8 | nadvoitsy
# Processing Record 43 of Set 8 | denpasar
# Processing Record 44 of Set 8 | porto novo
# Processing Record 45 of Set 8 | omsukchan
# Processing Record 46 of Set 8 | narsingi
# Processing Record 47 of Set 8 | madimba
# Processing Record 48 of Set 8 | siderno
# Processing Record 49 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 8 | xuanhua
# Processing Record 1 of Set 9 | praia da vitoria
# Processing Record 2 of Set 9 | alta floresta
# Processing Record 3 of Set 9 | egvekinot
# Processing Record 4 of Set 9 | manaus
# Processing Record 5 of Set 9 | moron
# Processing Record 6 of Set 9 | makokou
# Processing Record 7 of Set 9 | palora
# Processing Record 8 of Set 9 | rocha
# Processing Record 9 of Set 9 | krasnoarmeysk
# Processing Record 10 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 9 | zhicheng
# Processing Record 12 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 9 | vardo
# Processing Record 14 of Set 9 | gat
# Processing Record 15 of Set 9 | lesogorskiy
# Processing Record 16 of Set 9 | playa vicente
# Processing Record 17 of Set 9 | nalut
# Processing Record 18 of Set 9 | harper
# Processing Record 19 of Set 9 | big rapids
# Processing Record 20 of Set 9 | hirara
# Processing Record 21 of Set 9 | jabinyanah
# Processing Record 22 of Set 9 | voznesenye
# Processing Record 23 of Set 9 | acapulco
# Processing Record 24 of Set 9 | gravdal
# Processing Record 25 of Set 9 | katha
# City not found. Skipping...
# Processing Record 26 of Set 9 | aybak
# City not found. Skipping...
# Processing Record 27 of Set 9 | biltine
# Processing Record 28 of Set 9 | burnie
# Processing Record 29 of Set 9 | miyako
# Processing Record 30 of Set 9 | suna
# Processing Record 31 of Set 9 | kayerkan
# Processing Record 32 of Set 9 | viedma
# Processing Record 33 of Set 9 | terney
# Processing Record 34 of Set 9 | zlitan
# Processing Record 35 of Set 9 | kulotino
# Processing Record 36 of Set 9 | kungurtug
# Processing Record 37 of Set 9 | blagoveshchensk
# Processing Record 38 of Set 9 | boulder city
# Processing Record 39 of Set 9 | maceio
# Processing Record 40 of Set 9 | tuatapere
# Processing Record 41 of Set 9 | leh
# Processing Record 42 of Set 9 | antofagasta
# Processing Record 43 of Set 9 | grimshaw
# Processing Record 44 of Set 9 | marystown
# Processing Record 45 of Set 9 | pitimbu
# Processing Record 46 of Set 9 | los llanos de aridane
# Processing Record 47 of Set 9 | slave lake
# Processing Record 48 of Set 9 | uren
# Processing Record 49 of Set 9 | zhigansk
# Processing Record 50 of Set 9 | saint anthony
# Processing Record 1 of Set 10 | shaoguan
# Processing Record 2 of Set 10 | chunhuhub
# Processing Record 3 of Set 10 | french harbor
# Processing Record 4 of Set 10 | charters towers
# Processing Record 5 of Set 10 | jacqueville
# Processing Record 6 of Set 10 | suao
# City not found. Skipping...
# Processing Record 7 of Set 10 | nzega
# Processing Record 8 of Set 10 | vanimo
# Processing Record 9 of Set 10 | pringsewu
# Processing Record 10 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 10 | swellendam
# Processing Record 12 of Set 10 | douentza
# Processing Record 13 of Set 10 | alizai
# Processing Record 14 of Set 10 | kysyl-syr
# Processing Record 15 of Set 10 | antalaha
# Processing Record 16 of Set 10 | sao joao da barra
# Processing Record 17 of Set 10 | outjo
# Processing Record 18 of Set 10 | buta
# Processing Record 19 of Set 10 | porirua
# Processing Record 20 of Set 10 | mezen
# Processing Record 21 of Set 10 | zambezi
# Processing Record 22 of Set 10 | veraval
# Processing Record 23 of Set 10 | ankazoabo
# Processing Record 24 of Set 10 | paka
# Processing Record 25 of Set 10 | la ronge
# Processing Record 26 of Set 10 | mackay
# Processing Record 27 of Set 10 | teknaf
# Processing Record 28 of Set 10 | jimenez
# Processing Record 29 of Set 10 | palmas bellas
# Processing Record 30 of Set 10 | matay
# Processing Record 31 of Set 10 | kingori
# Processing Record 32 of Set 10 | iznik
# Processing Record 33 of Set 10 | oulainen
# Processing Record 34 of Set 10 | bahia de caraquez
# Processing Record 35 of Set 10 | palasa
# Processing Record 36 of Set 10 | alice springs
# Processing Record 37 of Set 10 | khandyga
# Processing Record 38 of Set 10 | zhangjiakou
# Processing Record 39 of Set 10 | kutum
# Processing Record 40 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 42 of Set 10 | esil
# Processing Record 43 of Set 10 | taoudenni
# Processing Record 44 of Set 10 | kiruna
# Processing Record 45 of Set 10 | namatanai
# Processing Record 46 of Set 10 | sangar
# Processing Record 47 of Set 10 | bathsheba
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | khani
# Processing Record 50 of Set 10 | loandjili
# Processing Record 1 of Set 11 | marrakesh
# Processing Record 2 of Set 11 | camana
# Processing Record 3 of Set 11 | terrace
# Processing Record 4 of Set 11 | vila velha
# Processing Record 5 of Set 11 | novopavlovka
# Processing Record 6 of Set 11 | babstovo
# Processing Record 7 of Set 11 | belyy yar
# Processing Record 8 of Set 11 | san quintin
# Processing Record 9 of Set 11 | havoysund
# Processing Record 10 of Set 11 | shitanjing
# Processing Record 11 of Set 11 | mocorito
# Processing Record 12 of Set 11 | ancud
# Processing Record 13 of Set 11 | traiguen
# Processing Record 14 of Set 11 | aswan
# Processing Record 15 of Set 11 | valleyview
# Processing Record 16 of Set 11 | khorol
# Processing Record 17 of Set 11 | vestby
# Processing Record 18 of Set 11 | wonthaggi
# Processing Record 19 of Set 11 | oktyabrskoye
# Processing Record 20 of Set 11 | sibolga
# Processing Record 21 of Set 11 | san pedro
# Processing Record 22 of Set 11 | tocopilla
# Processing Record 23 of Set 11 | boyolangu
# Processing Record 24 of Set 11 | colesberg
# Processing Record 25 of Set 11 | lulea
# Processing Record 26 of Set 11 | kaniama
# Processing Record 27 of Set 11 | mount pleasant
# Processing Record 28 of Set 11 | basoko
# Processing Record 29 of Set 11 | shaoyang
# Processing Record 30 of Set 11 | ust-tsilma
# Processing Record 31 of Set 11 | inta
# Processing Record 32 of Set 11 | ampanihy
# Processing Record 33 of Set 11 | kununurra
# Processing Record 34 of Set 11 | byron bay
# Processing Record 35 of Set 11 | aksu
# Processing Record 36 of Set 11 | palmares do sul
# Processing Record 37 of Set 11 | dalbandin
# Processing Record 38 of Set 11 | bilma
# Processing Record 39 of Set 11 | bogovina
# Processing Record 40 of Set 11 | sobolevo
# Processing Record 41 of Set 11 | comodoro rivadavia
# Processing Record 42 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 11 | saldanha
# Processing Record 44 of Set 11 | lostice
# Processing Record 45 of Set 11 | sibu
# Processing Record 46 of Set 11 | santander
# Processing Record 47 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 11 | umm lajj
# Processing Record 49 of Set 11 | cosamaloapan
# Processing Record 50 of Set 11 | shimanovsk
# Processing Record 1 of Set 12 | chara
# Processing Record 2 of Set 12 | otjimbingwe
# Processing Record 3 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 12 | tamandare
# Processing Record 5 of Set 12 | tecoanapa
# Processing Record 6 of Set 12 | karaton
# Processing Record 7 of Set 12 | fomboni
# Processing Record 8 of Set 12 | kirkenaer
# Processing Record 9 of Set 12 | bembereke
# Processing Record 10 of Set 12 | santa eulalia
# Processing Record 11 of Set 12 | huanren
# Processing Record 12 of Set 12 | nizhniy kuranakh
# Processing Record 13 of Set 12 | aykhal
# Processing Record 14 of Set 12 | padang
# Processing Record 15 of Set 12 | chimore
# Processing Record 16 of Set 12 | arlit
# Processing Record 17 of Set 12 | ondjiva
# Processing Record 18 of Set 12 | prattville
# Processing Record 19 of Set 12 | tateyama
# Processing Record 20 of Set 12 | shimoda
# Processing Record 21 of Set 12 | stamsund
# City not found. Skipping...
# Processing Record 22 of Set 12 | rincon
# Processing Record 23 of Set 12 | tucuman
# Processing Record 24 of Set 12 | rio bananal
# Processing Record 25 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 12 | contamana
# Processing Record 27 of Set 12 | klyuchi
# Processing Record 28 of Set 12 | qinzhou
# Processing Record 29 of Set 12 | vila franca do campo
# Processing Record 30 of Set 12 | abbeville
# Processing Record 31 of Set 12 | kazachinskoye
# Processing Record 32 of Set 12 | wagar
# Processing Record 33 of Set 12 | alaverdi
# Processing Record 34 of Set 12 | yinchuan
# Processing Record 35 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 12 | daru
# Processing Record 37 of Set 12 | bajitpur
# Processing Record 38 of Set 12 | dudinka
# Processing Record 39 of Set 12 | masallatah
# Processing Record 40 of Set 12 | mitsamiouli
# Processing Record 41 of Set 12 | kenai
# Processing Record 42 of Set 12 | devarkonda
# Processing Record 43 of Set 12 | yar-sale
# Processing Record 44 of Set 12 | ahero
# Processing Record 45 of Set 12 | kikwit
# Processing Record 46 of Set 12 | bubaque
# Processing Record 47 of Set 12 | natalio
# Processing Record 48 of Set 12 | portland
# Processing Record 49 of Set 12 | bozoum
# Processing Record 50 of Set 12 | mulchen
# Processing Record 1 of Set 13 | dharchula
# Processing Record 2 of Set 13 | torres
# Processing Record 3 of Set 13 | sistranda
# Processing Record 4 of Set 13 | hofu
# Processing Record 5 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 13 | boa vista
# Processing Record 7 of Set 13 | jasper
# Processing Record 8 of Set 13 | sabha
# Processing Record 9 of Set 13 | pangnirtung
# Processing Record 10 of Set 13 | tempio pausania
# Processing Record 11 of Set 13 | namibe
# Processing Record 12 of Set 13 | santa marta
# Processing Record 13 of Set 13 | waipawa
# Processing Record 14 of Set 13 | campbeltown
# Processing Record 15 of Set 13 | shenjiamen
# Processing Record 16 of Set 13 | kamloops
# Processing Record 17 of Set 13 | vangazi
# Processing Record 18 of Set 13 | severnyy
# Processing Record 19 of Set 13 | castel san giovanni
# Processing Record 20 of Set 13 | bata
# Processing Record 21 of Set 13 | cap malheureux
# Processing Record 22 of Set 13 | shiraz
# Processing Record 23 of Set 13 | ternate
# Processing Record 24 of Set 13 | kabalo
# Processing Record 25 of Set 13 | mecca
# Processing Record 26 of Set 13 | pastavy
# Processing Record 27 of Set 13 | mitu
# Processing Record 28 of Set 13 | mopti
# Processing Record 29 of Set 13 | nome
# Processing Record 30 of Set 13 | pouebo
# Processing Record 31 of Set 13 | tessalit
# Processing Record 32 of Set 13 | axim
# Processing Record 33 of Set 13 | tiarei
# Processing Record 34 of Set 13 | bend
# Processing Record 35 of Set 13 | kostyantynivka
# Processing Record 36 of Set 13 | tiznit
# Processing Record 37 of Set 13 | pishin
# Processing Record 38 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 13 | svetlogorsk
# Processing Record 40 of Set 13 | ginir
# Processing Record 41 of Set 13 | salinopolis
# Processing Record 42 of Set 13 | karratha
# Processing Record 43 of Set 13 | pilot butte
# Processing Record 44 of Set 13 | poplar bluff
# Processing Record 45 of Set 13 | ca mau
# Processing Record 46 of Set 13 | paamiut
# Processing Record 47 of Set 13 | belmonte
# Processing Record 48 of Set 13 | lithgow
# Processing Record 49 of Set 13 | tautira
# Processing Record 50 of Set 13 | silver city
# Processing Record 1 of Set 14 | manakara
# Processing Record 2 of Set 14 | tilichiki
# Processing Record 3 of Set 14 | fairbanks
# Processing Record 4 of Set 14 | ukiah
# Processing Record 5 of Set 14 | ambon
# Processing Record 6 of Set 14 | key west
# Processing Record 7 of Set 14 | nishihara
# Processing Record 8 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 14 | acajutla
# Processing Record 10 of Set 14 | ixtapa
# Processing Record 11 of Set 14 | astana
# Processing Record 12 of Set 14 | elizabeth city
# Processing Record 13 of Set 14 | mashhad
# Processing Record 14 of Set 14 | juneau
# Processing Record 15 of Set 14 | matir
# City not found. Skipping...
# Processing Record 16 of Set 14 | hadejia
# Processing Record 17 of Set 14 | rio grande
# Processing Record 18 of Set 14 | keti bandar
# Processing Record 19 of Set 14 | kilis
# Processing Record 20 of Set 14 | vedaranniyam
# City not found. Skipping...
# Processing Record 21 of Set 14 | prainha
# Processing Record 22 of Set 14 | tomatlan
# Processing Record 23 of Set 14 | deputatskiy
# Processing Record 24 of Set 14 | ponta delgada
# Processing Record 25 of Set 14 | manzhouli
# Processing Record 26 of Set 14 | tucumcari
# Processing Record 27 of Set 14 | bayji
# Processing Record 28 of Set 14 | athabasca
# Processing Record 29 of Set 14 | temyasovo
# Processing Record 30 of Set 14 | rambha
# Processing Record 31 of Set 14 | katangli
# Processing Record 32 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 14 | visby
# Processing Record 34 of Set 14 | hami
# Processing Record 35 of Set 14 | prince albert
# Processing Record 36 of Set 14 | port-gentil
# Processing Record 37 of Set 14 | tura
# Processing Record 38 of Set 14 | phan thiet
# Processing Record 39 of Set 14 | avera
# Processing Record 40 of Set 14 | carmen
# Processing Record 41 of Set 14 | port keats
# Processing Record 42 of Set 14 | sola
# Processing Record 43 of Set 14 | grand gaube
# Processing Record 44 of Set 14 | maxixe
# Processing Record 45 of Set 14 | likasi
# Processing Record 46 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 14 | nizhniy chir
# Processing Record 48 of Set 14 | burgos
# Processing Record 49 of Set 14 | mayo
# Processing Record 50 of Set 14 | manado
# Processing Record 1 of Set 15 | rosarito
# Processing Record 2 of Set 15 | kangaatsiaq
# Processing Record 3 of Set 15 | mount isa
# Processing Record 4 of Set 15 | tigil
# Processing Record 5 of Set 15 | maibong
# Processing Record 6 of Set 15 | beihai
# Processing Record 7 of Set 15 | price
# Processing Record 8 of Set 15 | shingu
# Processing Record 9 of Set 15 | magadan
# Processing Record 10 of Set 15 | koungou
# Processing Record 11 of Set 15 | dingle
# Processing Record 12 of Set 15 | utevka
# Processing Record 13 of Set 15 | buala
# Processing Record 14 of Set 15 | chabahar
# Processing Record 15 of Set 15 | kamenka
# Processing Record 16 of Set 15 | bartica
# Processing Record 17 of Set 15 | dubuque
# Processing Record 18 of Set 15 | promyshlennaya
# Processing Record 19 of Set 15 | taltal
# Processing Record 20 of Set 15 | goycay
# City not found. Skipping...
# Processing Record 21 of Set 15 | havre-saint-pierre
# Processing Record 22 of Set 15 | chernoistochinsk
# Processing Record 23 of Set 15 | half moon bay
# Processing Record 24 of Set 15 | troitsko-pechorsk
# Processing Record 25 of Set 15 | remedios
# Processing Record 26 of Set 15 | doha
# Processing Record 27 of Set 15 | gimli
# Processing Record 28 of Set 15 | kyzyl-suu
# Processing Record 29 of Set 15 | lixourion
# Processing Record 30 of Set 15 | izberbash
# Processing Record 31 of Set 15 | lakselv
# Processing Record 32 of Set 15 | pirovskoye
# Processing Record 33 of Set 15 | shambu
# Processing Record 34 of Set 15 | thunder bay
# Processing Record 35 of Set 15 | xuanzhou
# Processing Record 36 of Set 15 | jacareacanga
# Processing Record 37 of Set 15 | saint-francois
# Processing Record 38 of Set 15 | semey
# Processing Record 39 of Set 15 | port arthur
# Processing Record 40 of Set 15 | skjervoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 687

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Nyurba      RU  63.2842  118.3319    -20.51       100          99
# 1  Severo-Kurilsk      RU  50.6789  156.1250     28.29        81          35
# 2       Galveston      US  29.3669  -94.9669     75.09        39           0
# 3    Saint George      US  37.1041 -113.5841     73.94        15           0
# 4    Punta Arenas      CL -53.1500  -70.9167     60.91        63          75
# 5       Cape Town      ZA -33.9258   18.4232     64.81        78           0
# 6         Changli      CN  39.7042  119.1506     39.87        63          55
# 7           Tiksi      RU  71.6872  128.8694     -9.85        95         100
# 8        Lorengau      PG  -2.0226  147.2712     82.45        78          85
# 9      Bredasdorp      ZA -34.5322   20.0403     58.32        82          52
#
#    Wind Speed Current Description
# 0        2.89     overcast clouds
# 1        4.59    scattered clouds
# 2       11.99           clear sky
# 3        5.01           clear sky
# 4       29.93          light rain
# 5       13.80           clear sky
# 6       16.84       broken clouds
# 7        9.48     overcast clouds
# 8        8.50     overcast clouds
# 9        2.30       broken clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
